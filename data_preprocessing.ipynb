# %%
import pandas as pd
import numpy as np

# %%
import zipfile

# %%
df = pd.read_json('initial_data.json')
df
# Out:
#                    id affectedProduct  \
# 0       CVE-1999-0020           mitre
# 1       CVE-1999-0110           mitre
# 2       CVE-1999-0187           mitre
# 3       CVE-1999-0199           mitre
# 4       CVE-1999-0282           mitre
# ...               ...             ...
# 149913  CVE-2023-7298        autodesk
# 149914  CVE-2023-7299           vuldb
# 149915  CVE-2023-7300          huawei
# 149916  CVE-2023-7303           vuldb
# 149917  CVE-2023-7306       wordfence
#
#                                               description  cvssScore  \
# 0       Rejected reason: DO NOT USE THIS CANDIDATE NUM...        NaN
# 1       Rejected reason: DO NOT USE THIS CANDIDATE NUM...        NaN
# 2       Rejected reason: DO NOT USE THIS CANDIDATE NUM...        NaN
# 3       manual/search.texi in the GNU C Library (aka g...        9.8
# 4       Rejected reason: DO NOT USE THIS CANDIDATE NUM...        NaN
# ...                                                   ...        ...
# 149913  A maliciously crafted FBX file, when parsed th...        8.8
# 149914  A vulnerability was found in DataGear up to 4....        9.8
# 149915  Huawei Home Music System has a path traversal ...        NaN
# 149916  A vulnerability, which was classified as probl...        3.5
# 149917  The Frontend File Manager Plugin plugin for Wo...        7.5
#
#        availabilityImpact confidentialityImpact integrityImpact  \
# 0                    None                  None            None
# 1                    None                  None            None
# 2                    None                  None            None
# 3                    HIGH                  HIGH            HIGH
# 4                    None                  None            None
# ...                   ...                   ...             ...
# 149913               HIGH                  HIGH            HIGH
# 149914               HIGH                  HIGH            HIGH
# 149915               None                  None            None
# 149916               NONE                  NONE             LOW
# 149917               NONE                  NONE            HIGH
#
#        accessComplexity authenticationRequired  \
# 0                  None                   None
# 1                  None                   None
# 2                  None                   None
# 3                  None                   NONE
# 4                  None                   None
# ...                 ...                    ...
# 149913             None                   NONE
# 149914             None                   NONE
# 149915             None                   None
# 149916             None                    LOW
# 149917             None                   NONE
#
#                                                references publishedDate
# 0                                                      []    1999-01-01
# 1                                                      []    1999-01-01
# 2                                                      []    1999-01-01
# 3       [https://ftp.gnu.org/gnu/glibc/glibc-2.2.tar.g...    2020-10-06
# 4                                                      []    1997-09-23
# ...                                                   ...           ...
# 149913  [https://autodesk.com/trust/security-advisorie...    2024-12-09
# 149914  [https://github.com/datageartech/datagear/issu...    2024-11-23
# 149915  [https://www.huawei.com/en/psirt/security-advi...    2024-12-26
# 149916  [https://github.com/q2apro/q2apro-on-site-noti...    2025-05-07
# 149917  [https://plugins.trac.wordpress.org/changeset/...    2025-07-25
#
# [149918 rows x 11 columns]

# %%
df.count()
# Out:
# id                        149918
# affectedProduct           149906
# description               149918
# cvssScore                 129400
# availabilityImpact        129400
# confidentialityImpact     129400
# integrityImpact           129400
# accessComplexity            3863
# authenticationRequired    125537
# references                149918
# publishedDate             149918
# dtype: int64

# %%
# Here I am checking some CVE ID where availabilityImpact is null.
df_test = df[df['availabilityImpact'].isnull()]
df_test
# Out:
#                    id affectedProduct  \
# 0       CVE-1999-0020           mitre
# 1       CVE-1999-0110           mitre
# 2       CVE-1999-0187           mitre
# 4       CVE-1999-0282           mitre
# 5       CVE-1999-0335           mitre
# ...               ...             ...
# 149894  CVE-2023-7270     sec-consult
# 149897  CVE-2023-7273         cirosec
# 149911  CVE-2023-7296       wordfence
# 149912  CVE-2023-7297          wpscan
# 149915  CVE-2023-7300          huawei
#
#                                               description  cvssScore  \
# 0       Rejected reason: DO NOT USE THIS CANDIDATE NUM...        NaN
# 1       Rejected reason: DO NOT USE THIS CANDIDATE NUM...        NaN
# 2       Rejected reason: DO NOT USE THIS CANDIDATE NUM...        NaN
# 4       Rejected reason: DO NOT USE THIS CANDIDATE NUM...        NaN
# 5       Rejected reason: DO NOT USE THIS CANDIDATE NUM...        NaN
# ...                                                   ...        ...
# 149894  An issue was discovered in SoftMaker Office 20...        NaN
# 149897  Cross site request forgery in Kiteworks OwnClo...        NaN
# 149911  The BigBlueButton plugin for WordPress is vuln...        NaN
# 149912  The TwitterPosts WordPress plugin through 1.0....        NaN
# 149915  Huawei Home Music System has a path traversal ...        NaN
#
#        availabilityImpact confidentialityImpact integrityImpact  \
# 0                    None                  None            None
# 1                    None                  None            None
# 2                    None                  None            None
# 4                    None                  None            None
# 5                    None                  None            None
# ...                   ...                   ...             ...
# 149894               None                  None            None
# 149897               None                  None            None
# 149911               None                  None            None
# 149912               None                  None            None
# 149915               None                  None            None
#
#        accessComplexity authenticationRequired  \
# 0                  None                   None
# 1                  None                   None
# 2                  None                   None
# 4                  None                   None
# 5                  None                   None
# ...                 ...                    ...
# 149894             None                   None
# 149897             None                   None
# 149911             None                   None
# 149912             None                   None
# 149915             None                   None
#
#                                                references publishedDate
# 0                                                      []    1999-01-01
# 1                                                      []    1999-01-01
# 2                                                      []    1999-01-01
# 4                                                      []    1997-09-23
# 5                                                      []    1996-08-01
# ...                                                   ...           ...
# 149894  [http://seclists.org/fulldisclosure/2024/Jul/5...    2024-06-27
# 149897  [https://cirosec.de/sa/sa-2023-012, https://ha...    2024-10-01
# 149911  [https://www.wordfence.com/threat-intel/vulner...    2024-10-16
# 149912  [https://wpscan.com/vulnerability/3632dfa1-294...    2025-05-15
# 149915  [https://www.huawei.com/en/psirt/security-advi...    2024-12-26
#
# [20518 rows x 11 columns]

# %%
df_null_removed = df[df['availabilityImpact'].notnull()]

# %%
df_null_removed.head()
# Out:
#                  id affectedProduct  \
# 3     CVE-1999-0199           mitre
# 91   CVE-2002-20001           mitre
# 100   CVE-2002-2438          redhat
# 101   CVE-2002-2439          redhat
# 105   CVE-2002-2444           mitre
#
#                                            description  cvssScore  \
# 3    manual/search.texi in the GNU C Library (aka g...        9.8
# 91   The Diffie-Hellman Key Agreement Protocol allo...        7.5
# 100  TCP firewalls could be circumvented by sending...        7.5
# 101  Integer overflow in the new[] operator in gcc ...        7.8
# 105  Snoopy before 2.0.0 has a security hole in exe...        9.8
#
#     availabilityImpact confidentialityImpact integrityImpact accessComplexity  \
# 3                 HIGH                  HIGH            HIGH             None
# 91                HIGH                  NONE            NONE             None
# 100               HIGH                  NONE            NONE             None
# 101               HIGH                  HIGH            HIGH             None
# 105               HIGH                  HIGH            HIGH             None
#
#     authenticationRequired                                         references  \
# 3                     NONE  [https://ftp.gnu.org/gnu/glibc/glibc-2.2.tar.g...
# 91                    NONE  [https://cert-portal.siemens.com/productcert/p...
# 100                   NONE  [http://www.openwall.com/lists/oss-security/20...
# 101                    LOW  [https://access.redhat.com/security/cve/cve-20...
# 105                   NONE  [http://www.openwall.com/lists/oss-security/20...
#
#     publishedDate
# 3      2020-10-06
# 91     2021-11-11
# 100    2021-05-18
# 101    2019-10-23
# 105    2019-10-28

# %%
df_null_removed.count()
# Out:
# id                        129400
# affectedProduct           129396
# description               129400
# cvssScore                 129400
# availabilityImpact        129400
# confidentialityImpact     129400
# integrityImpact           129400
# accessComplexity            3863
# authenticationRequired    125537
# references                129400
# publishedDate             129400
# dtype: int64

# %%
df_test2 = df_null_removed[df_null_removed['affectedProduct'].isnull()]
df_test2.head()
# Out:
#                    id affectedProduct  \
# 17022  CVE-2018-10470            None
# 36673  CVE-2019-13013            None
# 36674  CVE-2019-13014            None
# 53611  CVE-2020-13095            None
#
#                                              description  cvssScore  \
# 17022  Little Snitch versions 4.0 to 4.0.6 use the Se...        5.3
# 36673  Little Snitch versions 4.3.0 to 4.3.2 have a l...        5.5
# 36674  Little Snitch versions 4.4.0 fixes a vulnerabi...        5.5
# 53611  Little Snitch version 4.5.1 and older changed ...        8.8
#
#       availabilityImpact confidentialityImpact integrityImpact  \
# 17022               NONE                  NONE             LOW
# 36673               NONE                  HIGH            NONE
# 36674               NONE                  HIGH            NONE
# 53611               HIGH                  HIGH            HIGH
#
#       accessComplexity authenticationRequired  \
# 17022             None                   NONE
# 36673             None                    LOW
# 36674             None                    LOW
# 53611             None                    LOW
#
#                                               references publishedDate
# 17022  [https://obdev.at/cve/2018-10470-8FRWkW4oH8.ht...    2018-06-12
# 36673  [https://obdev.at/cve/2019-13013-OSv2mEFD3z.ht...    2019-08-23
# 36674  [https://obdev.at/cve/2019-13014-MzE24Ify4p.ht...    2019-08-23
# 53611  [https://obdev.at/cve/2020-13095-t46oXJJOwz.ht...    2020-06-30

# %%
df_null_removed['affectedProduct'] = df_null_removed['affectedProduct'].fillna("NONE")
df_null_removed['authenticationRequired'] = df_null_removed['authenticationRequired'].fillna("NONE")
df_null_removed['accessComplexity'] = df_null_removed['accessComplexity'].fillna("NONE")
# Out:
# C:\Users\shrus\AppData\Local\Temp/ipykernel_16440/996598866.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_null_removed['affectedProduct'] = df_null_removed['affectedProduct'].fillna("NONE")
# C:\Users\shrus\AppData\Local\Temp/ipykernel_16440/996598866.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_null_removed['authenticationRequired'] = df_null_removed['authenticationRequired'].fillna("NONE")
# C:\Users\shrus\AppData\Local\Temp/ipykernel_16440/996598866.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_null_removed['accessComplexity'] = df_null_removed['accessComplexity'].fillna("NONE")

# %%
df_null_removed.count()
# Out:
# id                        129400
# affectedProduct           129400
# description               129400
# cvssScore                 129400
# availabilityImpact        129400
# confidentialityImpact     129400
# integrityImpact           129400
# accessComplexity          129400
# authenticationRequired    129400
# references                129400
# publishedDate             129400
# dtype: int64

# %%
import json
json_output = df_null_removed.to_dict(orient="records")

json_string = json.dumps(json_output, indent=4)

# %%
with open("final_data.json", "w") as file:
    json.dump(json_output, file, indent=4)
